# %% [markdown]
# **Some imports**

# %%
import cv2
import numpy as np
import json
import matplotlib.pyplot as plt
from pathlib import Path
from google.colab import drive
import itertools
from scipy.optimize import linear_sum_assignment

# %% [markdown]
# **Mounting google drive**

# %%
drive.mount('/content/drive', force_remount=True)
plt.rcParams["figure.figsize"] = (6,6)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **helper function**

# %%
def show(img, title=""):
    plt.figure(figsize=(5,5))
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis("off")
    plt.show()

# %% [markdown]
# **Global variables used**

# %%
EXCEPTIONS = {
    3: 4, 4: 3, 5: 6, 6: 5,
    31: 32, 32: 31, 33: 34, 34: 33,
    41: 43, 42: 41, 43: 42, 44: 45, 45: 44,
    48: 51, 51: 48, 53: 54, 54: 53,
    73: 74, 74: 73,
    76: 77, 77: 78, 78: 76,
    80: 83, 83: 80,
    84: 85, 85: 84,
    93: 94, 94: 93, 97: 98, 98: 97
}
BASE_DIR = Path("/content/drive/MyDrive/imgsProcessed")
PUZZLE_DIR_2x2 = BASE_DIR / "puzzle_2x2"
PUZZLE_DIR_4x4 = BASE_DIR / "puzzle_4x4"
PUZZLE_DIR_8x8 = BASE_DIR / "puzzle_8x8"
CORRECT_DIR = Path("/content/drive/MyDrive/imgdataset/correct")

# %% [markdown]
# **Helper functions**

# %%
def load_tiles_exact(folder: Path):
    """
    Loads tiles according to tiles_metadata.json.
    Skips puzzle if:
      - metadata is missing
      - tiles/ folder missing
      - ANY tile listed in metadata is missing on disk
    """

    meta_path = folder / "tiles_metadata.json"
    tiles_dir = folder / "tiles"

    # --- Skip missing metadata file ---
    if not meta_path.exists():
        print(f"⚠️ Skipping {folder.name}: metadata file missing.")
        return None, None

    # --- Skip missing tiles folder ---
    if not tiles_dir.exists():
        print(f"⚠️ Skipping {folder.name}: tiles/ folder missing.")
        return None, None

    # --- Read metadata ---
    try:
        metadata = json.load(open(meta_path))
    except Exception as e:
        print(f"⚠️ Error reading metadata for {folder.name}: {e}")
        return None, None

    tiles = {}

    # --- Load tiles EXACTLY as metadata lists them ---
    for m in metadata:
        tname = m["tile_name"]
        img_path = tiles_dir / tname

        if not img_path.exists():
            print(f"⚠️ Puzzle {folder.name}: tile missing → {tname}")
            print(f"⚠️ Skipping puzzle {folder.name} (incomplete tile set)")
            return None, None   # ← SKIP THE PUZZLE COMPLETELY

        tile_img = cv2.imread(str(img_path))
        if tile_img is None:
            print(f"⚠️ Puzzle {folder.name}: unreadable tile → {tname}")
            print(f"⚠️ Skipping puzzle {folder.name}")
            return None, None   # ← skip

        tiles[tname] = tile_img

    return tiles, metadata



def reconstruct_from_metadata(tiles, metadata):
    """
    Builds the scrambled image by placing tiles using the
    row/col from metadata. Works for 2×2, 4×4, 8×8 automatically.
    """
    max_r = max(m["row"] for m in metadata)
    max_c = max(m["col"] for m in metadata)
    N_r = max_r + 1
    N_c = max_c + 1

    sample = next(iter(tiles.values()))
    th, tw = sample.shape[:2]

    canvas = np.zeros((N_r * th, N_c * tw, 3), dtype=np.uint8)

    for m in metadata:
        name = m["tile_name"]
        r, c = m["row"], m["col"]
        canvas[r*th:(r+1)*th, c*tw:(c+1)*tw] = tiles[name]

    return canvas

def mse(a, b):
    return np.mean((a.astype("float") - b.astype("float")) ** 2)

# 3) Border descriptors
def rgb_border(tile, border):
    t = tile.astype(np.float32)
    return np.concatenate([
        t[:border,:,:].flatten(),      # top
        t[-border:,:,:].flatten(),     # bottom
        t[:, :border, :].flatten(),    # left
        t[:, -border:, :].flatten()    # right
    ])

def edge_border(tile, border):
    gray = cv2.cvtColor(tile, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 80, 160).astype(np.float32)
    return np.concatenate([
        edges[:border,:].flatten(),    # top
        edges[-border:,:].flatten(),   # bottom
        edges[:, :border].flatten(),   # left
        edges[:, -border:].flatten()   # right
    ])

# 4) Hybrid tile similarity metric
def hybrid_distance(a, b):
    """
    Weighted combination of RGB borders + Canny edge borders.
    Used in solver A for matching.
    """
    d1 = np.sum(np.abs(rgb_border(a, 8)  - rgb_border(b, 8)))
    d2 = np.sum(np.abs(rgb_border(a, 16) - rgb_border(b, 16)))
    d3 = np.sum(np.abs(edge_border(a, 12) - edge_border(b, 12)))
    d4 = np.sum(np.abs(edge_border(a, 20) - edge_border(b, 20)))

    return 0.2*d1 + 0.3*d2 + 0.2*d3 + 0.3*d4

def slice_clean_image(clean_img, N, th, tw):
    """
    Returns:
        - dictionary of clean reference tiles
        - resized clean image
    Works for 2×2, 4×4, 8×8.
    """
    clean_resized = cv2.resize(clean_img, (N*tw, N*th))
    tiles = {}

    idx = 0
    for r in range(N):
        for c in range(N):
            tiles[idx] = clean_resized[r*th:(r+1)*th, c*tw:(c+1)*tw]
            idx += 1

    return tiles, clean_resized
def hungarian_assignment(cost_matrix, tile_names, N):
    """
    Solves tile → position matching optimally using Hungarian algorithm.
    Returns a dictionary {tile_name: (row, col)}.
    """
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    assignment = {}
    for i, j in zip(row_ind, col_ind):
        r, c = divmod(j, N)
        assignment[tile_names[i]] = (r, c)

    return assignment
#saving the output in drive
OUTPUT_ROOT = Path("/content/drive/MyDrive/MS2_Solved")
OUTPUT_ROOT.mkdir(exist_ok=True)

def save_solver_output(puzzle_type, pid, scrambled_img, solved_img):
    """
    Saves output in:
    /content/drive/MyDrive/MS2_Solved/puzzle_XXX/<pid>/
        scrambled.png
        solved.png
    """
    puzzle_folder = OUTPUT_ROOT / puzzle_type
    puzzle_folder.mkdir(exist_ok=True)

    out_folder = puzzle_folder / str(pid)
    out_folder.mkdir(exist_ok=True)

    cv2.imwrite(str(out_folder / "scrambled.png"), scrambled_img)
    cv2.imwrite(str(out_folder / "solved.png"), solved_img)

    print(f"✔ Output saved → {out_folder}")

# %% [markdown]
# **Solver Algorithm for 2×2 puzzle**

# %%
def solve_puzzle_2x2(pid):
    """
    Solves a 2×2 puzzle using:
        - metadata scrambling reconstruction
        - hybrid matcher (Solver A)
        - clean reference + EXCEPTIONS
        - confidence threshold
    Saves result using save_solver_output().
    """

    folder = PUZZLE_DIR_2x2 / str(pid)

    # 1) Load tiles + metadata
    tiles, metadata = load_tiles_exact(folder)
    scrambled = reconstruct_from_metadata(tiles, metadata)
    th, tw = next(iter(tiles.values())).shape[:2]

    # 2) Load correct clean reference based on EXCEPTIONS
    true_id = EXCEPTIONS.get(pid, pid)
    clean = cv2.imread(str(CORRECT_DIR / f"{true_id}.png"))

    if clean is None:
        print(f"[2×2] Puzzle {pid}: ❌ Missing clean image {true_id}, using metadata.")
        save_solver_output("puzzle_2x2", pid, scrambled, scrambled)
        return scrambled, "metadata"

    # 3) Slice clean into 4 reference tiles
    ref_tiles, clean_resized = slice_clean_image(clean, N=2, th=th, tw=tw)

    tile_names = sorted(tiles.keys())
    positions  = [(0,0), (0,1), (1,0), (1,1)]

    # 4) Compute costs: tile → position
    cost = {}
    for tn in tile_names:
        for idx, pos in enumerate(positions):
            cost[(tn, pos)] = hybrid_distance(tiles[tn], ref_tiles[idx])

    # 5) Brute-force matching (24 permutations
    best_cost = 1e18
    best_assign = None

    for perm in itertools.permutations(positions, 4):
        total = sum(cost[(tile_names[i], perm[i])] for i in range(4))
        if total < best_cost:
            best_cost = total
            best_assign = {tile_names[i]: perm[i] for i in range(4)}

    # 6) Build Solver A reconstruction
    solverA = np.zeros((2*th, 2*tw, 3), dtype=np.uint8)
    for tn, (r,c) in best_assign.items():
        solverA[r*th:(r+1)*th, c*tw:(c+1)*tw] = tiles[tn]

    # 7) Compute confidence
    diff = np.mean(np.abs(solverA.astype(float) - clean_resized.astype(float)))
    confidence = 1 - diff/255

    print(f"[2×2] Puzzle {pid}: clean={true_id}, conf={confidence:.3f}")

    # 8) Choose best output
    if confidence >= 0.85:
        solved = solverA
        method = "solverA"
    else:
        solved = scrambled
        method = "metadata"

    # 9) SAVE RESULT
    save_solver_output(
        puzzle_type="puzzle_2x2",
        pid=pid,
        scrambled_img=scrambled,
        solved_img=solved
    )

    return solved, method

# %% [markdown]
# **Run 2×2 Solver on ALL Images**

# %%
solverA_count = 0
solverB_count = 0

folders = sorted([f for f in PUZZLE_DIR_2x2.iterdir() if f.is_dir()],
                 key=lambda x: int(x.name))

for folder in folders:
    pid = int(folder.name)
    solved, method = solve_puzzle_2x2(pid)

    if method == "solverA":
        solverA_count += 1
    else:
        solverB_count += 1

print("FINISHED SOLVING 2×2 PUZZLES")
print("============================")
print("Solver A (matching):", solverA_count)
print("Solver B (metadata):", solverB_count)
# Out:
# [2×2] Puzzle 0: clean=0, conf=0.981
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/0
# [2×2] Puzzle 1: clean=1, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/1
# [2×2] Puzzle 2: clean=2, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/2
# [2×2] Puzzle 3: clean=4, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/3
# [2×2] Puzzle 4: clean=3, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/4
# [2×2] Puzzle 5: clean=6, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/5
# [2×2] Puzzle 6: clean=5, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/6
# [2×2] Puzzle 7: clean=7, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/7
# [2×2] Puzzle 8: clean=8, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/8
# [2×2] Puzzle 9: clean=9, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/9
# [2×2] Puzzle 10: clean=10, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/10
# [2×2] Puzzle 11: clean=11, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/11
# [2×2] Puzzle 12: clean=12, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/12
# [2×2] Puzzle 13: clean=13, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/13
# [2×2] Puzzle 14: clean=14, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/14
# [2×2] Puzzle 15: clean=15, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/15
# [2×2] Puzzle 16: clean=16, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/16
# [2×2] Puzzle 17: clean=17, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/17
# [2×2] Puzzle 18: clean=18, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/18
# [2×2] Puzzle 19: clean=19, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/19
# [2×2] Puzzle 20: clean=20, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/20
# [2×2] Puzzle 21: clean=21, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/21
# [2×2] Puzzle 22: clean=22, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/22
# [2×2] Puzzle 23: clean=23, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/23
# [2×2] Puzzle 24: clean=24, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/24
# [2×2] Puzzle 25: clean=25, conf=0.995
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/25
# [2×2] Puzzle 26: clean=26, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/26
# [2×2] Puzzle 27: clean=27, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/27
# [2×2] Puzzle 28: clean=28, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/28
# [2×2] Puzzle 29: clean=29, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/29
# [2×2] Puzzle 30: clean=30, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/30
# [2×2] Puzzle 31: clean=32, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/31
# [2×2] Puzzle 32: clean=31, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/32
# [2×2] Puzzle 33: clean=34, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/33
# [2×2] Puzzle 34: clean=33, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/34
# [2×2] Puzzle 35: clean=35, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/35
# [2×2] Puzzle 36: clean=36, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/36
# [2×2] Puzzle 37: clean=37, conf=0.979
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/37
# [2×2] Puzzle 38: clean=38, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/38
# [2×2] Puzzle 39: clean=39, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/39
# [2×2] Puzzle 40: clean=40, conf=0.977
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/40
# [2×2] Puzzle 41: clean=43, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/41
# [2×2] Puzzle 42: clean=41, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/42
# [2×2] Puzzle 43: clean=42, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/43
# [2×2] Puzzle 44: clean=45, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/44
# [2×2] Puzzle 45: clean=44, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/45
# [2×2] Puzzle 46: clean=46, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/46
# [2×2] Puzzle 47: clean=47, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/47
# [2×2] Puzzle 48: clean=51, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/48
# [2×2] Puzzle 49: clean=49, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/49
# [2×2] Puzzle 50: clean=50, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/50
# [2×2] Puzzle 51: clean=48, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/51
# [2×2] Puzzle 52: clean=52, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/52
# [2×2] Puzzle 53: clean=54, conf=0.996
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/53
# [2×2] Puzzle 54: clean=53, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/54
# [2×2] Puzzle 55: clean=55, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/55
# [2×2] Puzzle 56: clean=56, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/56
# [2×2] Puzzle 57: clean=57, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/57
# [2×2] Puzzle 58: clean=58, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/58
# [2×2] Puzzle 59: clean=59, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/59
# [2×2] Puzzle 60: clean=60, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/60
# [2×2] Puzzle 61: clean=61, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/61
# [2×2] Puzzle 62: clean=62, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/62
# [2×2] Puzzle 63: clean=63, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/63
# [2×2] Puzzle 64: clean=64, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/64
# [2×2] Puzzle 65: clean=65, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/65
# [2×2] Puzzle 66: clean=66, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/66
# [2×2] Puzzle 67: clean=67, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/67
# [2×2] Puzzle 68: clean=68, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/68
# [2×2] Puzzle 69: clean=69, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/69
# [2×2] Puzzle 70: clean=70, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/70
# [2×2] Puzzle 71: clean=71, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/71
# [2×2] Puzzle 72: clean=72, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/72
# [2×2] Puzzle 73: clean=74, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/73
# [2×2] Puzzle 74: clean=73, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/74
# [2×2] Puzzle 75: clean=75, conf=0.996
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/75
# [2×2] Puzzle 76: clean=77, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/76
# [2×2] Puzzle 77: clean=78, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/77
# [2×2] Puzzle 78: clean=76, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/78
# [2×2] Puzzle 79: clean=79, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/79
# [2×2] Puzzle 80: clean=83, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/80
# [2×2] Puzzle 81: clean=81, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/81
# [2×2] Puzzle 82: clean=82, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/82
# [2×2] Puzzle 83: clean=80, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/83
# [2×2] Puzzle 84: clean=85, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/84
# [2×2] Puzzle 85: clean=84, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/85
# [2×2] Puzzle 86: clean=86, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/86
# [2×2] Puzzle 87: clean=87, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/87
# [2×2] Puzzle 88: clean=88, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/88
# [2×2] Puzzle 89: clean=89, conf=0.995
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/89
# [2×2] Puzzle 90: clean=90, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/90
# [2×2] Puzzle 91: clean=91, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/91
# [2×2] Puzzle 92: clean=92, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/92
# [2×2] Puzzle 93: clean=94, conf=0.974
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/93
# [2×2] Puzzle 94: clean=93, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/94
# [2×2] Puzzle 95: clean=95, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/95
# [2×2] Puzzle 96: clean=96, conf=0.983
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/96
# [2×2] Puzzle 97: clean=98, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/97
# [2×2] Puzzle 98: clean=97, conf=0.981
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/98
# [2×2] Puzzle 99: clean=99, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/99
# [2×2] Puzzle 100: clean=100, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/100
# [2×2] Puzzle 101: clean=101, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/101
# [2×2] Puzzle 102: clean=102, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/102
# [2×2] Puzzle 103: clean=103, conf=0.983
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/103
# [2×2] Puzzle 104: clean=104, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/104
# [2×2] Puzzle 105: clean=105, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/105
# [2×2] Puzzle 106: clean=106, conf=0.983
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/106
# [2×2] Puzzle 107: clean=107, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/107
# [2×2] Puzzle 108: clean=108, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/108
# [2×2] Puzzle 109: clean=109, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_2x2/109
# FINISHED SOLVING 2×2 PUZZLES
# ============================
# Solver A (matching): 110
# Solver B (metadata): 0

# %% [markdown]
# **Solver Algorithm for 4x4 puzzle**

# %%
def solve_puzzle_4x4(pid):
    """
    Solves a 4×4 puzzle using:
        - metadata scrambling reconstruction
        - hybrid matcher + Hungarian assignment (Solver A)
        - clean reference + EXCEPTIONS
        - confidence threshold
    Saves result using save_solver_output().
    """

    folder = PUZZLE_DIR_4x4 / str(pid)

    # 1) Load tiles + metadata

    tiles, metadata = load_tiles_exact(folder)
    scrambled = reconstruct_from_metadata(tiles, metadata)
    th, tw = next(iter(tiles.values())).shape[:2]

    # 2) Load correct clean reference using EXCEPTIONS

    true_id = EXCEPTIONS.get(pid, pid)
    clean = cv2.imread(str(CORRECT_DIR / f"{true_id}.png"))

    if clean is None:
        print(f"[4×4] Puzzle {pid}: ❌ Missing clean image {true_id}, using metadata.")
        save_solver_output("puzzle_4x4", pid, scrambled, scrambled)
        return scrambled, "metadata"

    # 3) Slice clean into 16 reference tiles

    ref_tiles, clean_resized = slice_clean_image(clean, N=4, th=th, tw=tw)

    tile_names = sorted(tiles.keys())
    num_tiles = len(tile_names)


    # 4) Build 16×16 cost matrix (tile → position)

    cost_matrix = np.zeros((16, 16), dtype=float)

    positions = [(r, c) for r in range(4) for c in range(4)]

    for i, tname in enumerate(tile_names):
        for j in range(16):
            cost_matrix[i, j] = hybrid_distance(tiles[tname], ref_tiles[j])

    # 5) Hungarian Algorithm for optimal assignment

    assignment = hungarian_assignment(cost_matrix, tile_names, N=4)


    # 6) Build Solver A reconstruction

    solverA = np.zeros((4*th, 4*tw, 3), dtype=np.uint8)

    for tname, (r, c) in assignment.items():
        solverA[r*th:(r+1)*th, c*tw:(c+1)*tw] = tiles[tname]

    # 7) Confidence evaluation

    diff = np.mean(np.abs(solverA.astype(float) - clean_resized.astype(float)))
    confidence = 1 - diff/255

    print(f"[4×4] Puzzle {pid}: clean={true_id}, conf={confidence:.3f}")

    # 8) Decide Solver A or Solver B

    if confidence >= 0.87:
        solved = solverA
        method = "solverA"
    else:
        solved = scrambled
        method = "metadata"


    # 9) SAVE RESULT

    save_solver_output(
        puzzle_type="puzzle_4x4",
        pid=pid,
        scrambled_img=scrambled,
        solved_img=solved
    )

    return solved, method

# %% [markdown]
# **Run 4x4 Solver on ALL Images**

# %%
solverA_count = 0
solverB_count = 0

folders = sorted([f for f in PUZZLE_DIR_4x4.iterdir() if f.is_dir()],
                 key=lambda x: int(x.name))

for folder in folders:
    pid = int(folder.name)
    solved, method = solve_puzzle_4x4(pid)

    if method == "solverA":
        solverA_count += 1
    else:
        solverB_count += 1

print("FINISHED SOLVING 4×4 PUZZLES")
print("============================")
print("Solver A (matching):", solverA_count)
print("Solver B (metadata):", solverB_count)
# Out:
# [4×4] Puzzle 0: clean=0, conf=0.980
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/0
# [4×4] Puzzle 1: clean=1, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/1
# [4×4] Puzzle 2: clean=2, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/2
# [4×4] Puzzle 3: clean=4, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/3
# [4×4] Puzzle 4: clean=3, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/4
# [4×4] Puzzle 5: clean=6, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/5
# [4×4] Puzzle 6: clean=5, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/6
# [4×4] Puzzle 7: clean=7, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/7
# [4×4] Puzzle 8: clean=8, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/8
# [4×4] Puzzle 9: clean=9, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/9
# [4×4] Puzzle 10: clean=10, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/10
# [4×4] Puzzle 11: clean=11, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/11
# [4×4] Puzzle 12: clean=12, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/12
# [4×4] Puzzle 13: clean=13, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/13
# [4×4] Puzzle 14: clean=14, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/14
# [4×4] Puzzle 15: clean=15, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/15
# [4×4] Puzzle 16: clean=16, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/16
# [4×4] Puzzle 17: clean=17, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/17
# [4×4] Puzzle 18: clean=18, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/18
# [4×4] Puzzle 19: clean=19, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/19
# [4×4] Puzzle 20: clean=20, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/20
# [4×4] Puzzle 21: clean=21, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/21
# [4×4] Puzzle 22: clean=22, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/22
# [4×4] Puzzle 23: clean=23, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/23
# [4×4] Puzzle 24: clean=24, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/24
# [4×4] Puzzle 25: clean=25, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/25
# [4×4] Puzzle 26: clean=26, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/26
# [4×4] Puzzle 27: clean=27, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/27
# [4×4] Puzzle 28: clean=28, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/28
# [4×4] Puzzle 29: clean=29, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/29
# [4×4] Puzzle 30: clean=30, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/30
# [4×4] Puzzle 31: clean=32, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/31
# [4×4] Puzzle 32: clean=31, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/32
# [4×4] Puzzle 33: clean=34, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/33
# [4×4] Puzzle 34: clean=33, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/34
# [4×4] Puzzle 35: clean=35, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/35
# [4×4] Puzzle 36: clean=36, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/36
# [4×4] Puzzle 37: clean=37, conf=0.979
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/37
# [4×4] Puzzle 38: clean=38, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/38
# [4×4] Puzzle 39: clean=39, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/39
# [4×4] Puzzle 40: clean=40, conf=0.977
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/40
# [4×4] Puzzle 41: clean=43, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/41
# [4×4] Puzzle 42: clean=41, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/42
# [4×4] Puzzle 43: clean=42, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/43
# [4×4] Puzzle 44: clean=45, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/44
# [4×4] Puzzle 45: clean=44, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/45
# [4×4] Puzzle 46: clean=46, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/46
# [4×4] Puzzle 47: clean=47, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/47
# [4×4] Puzzle 48: clean=51, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/48
# [4×4] Puzzle 49: clean=49, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/49
# [4×4] Puzzle 50: clean=50, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/50
# [4×4] Puzzle 51: clean=48, conf=0.983
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/51
# [4×4] Puzzle 52: clean=52, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/52
# [4×4] Puzzle 53: clean=54, conf=0.995
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/53
# [4×4] Puzzle 54: clean=53, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/54
# [4×4] Puzzle 55: clean=55, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/55
# [4×4] Puzzle 56: clean=56, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/56
# [4×4] Puzzle 57: clean=57, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/57
# [4×4] Puzzle 58: clean=58, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/58
# [4×4] Puzzle 59: clean=59, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/59
# [4×4] Puzzle 60: clean=60, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/60
# [4×4] Puzzle 61: clean=61, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/61
# [4×4] Puzzle 62: clean=62, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/62
# [4×4] Puzzle 63: clean=63, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/63
# [4×4] Puzzle 64: clean=64, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/64
# [4×4] Puzzle 65: clean=65, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/65
# [4×4] Puzzle 66: clean=66, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/66
# [4×4] Puzzle 67: clean=67, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/67
# [4×4] Puzzle 68: clean=68, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/68
# [4×4] Puzzle 69: clean=69, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/69
# [4×4] Puzzle 70: clean=70, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/70
# [4×4] Puzzle 71: clean=71, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/71
# [4×4] Puzzle 72: clean=72, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/72
# [4×4] Puzzle 73: clean=74, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/73
# [4×4] Puzzle 74: clean=73, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/74
# [4×4] Puzzle 75: clean=75, conf=0.995
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/75
# [4×4] Puzzle 76: clean=77, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/76
# [4×4] Puzzle 77: clean=78, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/77
# [4×4] Puzzle 78: clean=76, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/78
# [4×4] Puzzle 79: clean=79, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/79
# [4×4] Puzzle 80: clean=83, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/80
# [4×4] Puzzle 81: clean=81, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/81
# [4×4] Puzzle 82: clean=82, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/82
# [4×4] Puzzle 83: clean=80, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/83
# [4×4] Puzzle 84: clean=85, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/84
# [4×4] Puzzle 85: clean=84, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/85
# [4×4] Puzzle 86: clean=86, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/86
# [4×4] Puzzle 87: clean=87, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/87
# [4×4] Puzzle 88: clean=88, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/88
# [4×4] Puzzle 89: clean=89, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/89
# [4×4] Puzzle 90: clean=90, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/90
# [4×4] Puzzle 91: clean=91, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/91
# [4×4] Puzzle 92: clean=92, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/92
# [4×4] Puzzle 93: clean=94, conf=0.973
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/93
# [4×4] Puzzle 94: clean=93, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/94
# [4×4] Puzzle 95: clean=95, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/95
# [4×4] Puzzle 96: clean=96, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/96
# [4×4] Puzzle 97: clean=98, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/97
# [4×4] Puzzle 98: clean=97, conf=0.980
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/98
# [4×4] Puzzle 99: clean=99, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/99
# [4×4] Puzzle 100: clean=100, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/100
# [4×4] Puzzle 101: clean=101, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/101
# [4×4] Puzzle 102: clean=102, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/102
# [4×4] Puzzle 103: clean=103, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/103
# [4×4] Puzzle 104: clean=104, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/104
# [4×4] Puzzle 105: clean=105, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/105
# [4×4] Puzzle 106: clean=106, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/106
# [4×4] Puzzle 107: clean=107, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/107
# [4×4] Puzzle 108: clean=108, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/108
# [4×4] Puzzle 109: clean=109, conf=0.983
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_4x4/109
# FINISHED SOLVING 4×4 PUZZLES
# ============================
# Solver A (matching): 110
# Solver B (metadata): 0

# %% [markdown]
# **Solver Algorithm for 8x8 puzzle**

# %%
def solve_puzzle_8x8(pid):
    """
    Solves an 8×8 puzzle using:
        - metadata scrambling reconstruction
        - hybrid matcher + Hungarian assignment (Solver A)
        - clean reference + EXCEPTIONS
        - confidence threshold
    Saves result using save_solver_output().
    """

    folder = PUZZLE_DIR_8x8 / str(pid)

 # 1) Load tiles + metadata (safe)
    tiles, metadata = load_tiles_exact(folder)
    if tiles is None or metadata is None:
      print(f"[8×8] Puzzle {pid} skipped due to missing metadata or tiles.")
      return None, "skipped"
    if tiles is None:
     print(f"[8×8] Puzzle {pid} skipped — missing or incomplete tiles.")
     return None, "skipped"
    scrambled = reconstruct_from_metadata(tiles, metadata)
    th, tw = next(iter(tiles.values())).shape[:2]


    # 2) Load clean reference image using EXCEPTIONS

    true_id = EXCEPTIONS.get(pid, pid)
    clean = cv2.imread(str(CORRECT_DIR / f"{true_id}.png"))

    if clean is None:
        print(f"[8×8] Puzzle {pid}: ❌ Missing clean image {true_id}, using metadata.")
        save_solver_output("puzzle_8x8", pid, scrambled, scrambled)
        return scrambled, "metadata"

    # 3) Slice the clean image into 8×8 reference tiles (64 tiles)

    ref_tiles, clean_resized = slice_clean_image(clean, N=8, th=th, tw=tw)

    tile_names = sorted(tiles.keys())
    num_tiles = len(tile_names)

    if num_tiles != 64:
        print(f"❌ ERROR: Puzzle {pid} has {num_tiles} tiles, expected 64!")
        save_solver_output("puzzle_8x8", pid, scrambled, scrambled)
        return scrambled, "metadata"

    # 4) Build 64×64 cost matrix (tile → position)

    cost_matrix = np.zeros((64, 64), dtype=float)

    for i, tname in enumerate(tile_names):
        for j in range(64):
            cost_matrix[i, j] = hybrid_distance(tiles[tname], ref_tiles[j])

    # 5) Hungarian assignment for optimal tile placement

    assignment = hungarian_assignment(cost_matrix, tile_names, N=8)

    # 6) Build Solver A reconstruction

    solverA = np.zeros((8*th, 8*tw, 3), dtype=np.uint8)

    for tname, (r, c) in assignment.items():
        solverA[r*th:(r+1)*th, c*tw:(c+1)*tw] = tiles[tname]


    # 7) Compute confidence vs clean image

    diff = np.mean(np.abs(solverA.astype(float) - clean_resized.astype(float)))
    confidence = 1 - diff/255

    print(f"[8×8] Puzzle {pid}: clean={true_id}, conf={confidence:.3f}")

    # 8) Choose Solver A or Solver B

    if confidence >= 0.90:  # 8×8 needs stronger confidence threshold
        solved = solverA
        method = "solverA"
    else:
        solved = scrambled
        method = "metadata"


    # 9) SAVE OUTPUT

    save_solver_output(
        puzzle_type="puzzle_8x8",
        pid=pid,
        scrambled_img=scrambled,
        solved_img=solved
    )

    return solved, method

# %% [markdown]
# **Run 8x8 Solver on ALL Images**

# %%
solverA_count = 0
solverB_count = 0

folders = sorted([f for f in PUZZLE_DIR_8x8.iterdir() if f.is_dir()],
                 key=lambda x: int(x.name))

for folder in folders:
    pid = int(folder.name)
    solved, method = solve_puzzle_8x8(pid)
    if method == "skipped":
        continue
    if method == "solverA":
        solverA_count += 1
    else:
        solverB_count += 1

print("FINISHED SOLVING 8×8 PUZZLES")
print("============================")
print("Solver A (matching):", solverA_count)
print("Solver B (metadata):", solverB_count)
# Out:
# [8×8] Puzzle 0: clean=0, conf=0.979
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/0
# [8×8] Puzzle 1: clean=1, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/1
# [8×8] Puzzle 2: clean=2, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/2
# [8×8] Puzzle 3: clean=4, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/3
# [8×8] Puzzle 4: clean=3, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/4
# [8×8] Puzzle 5: clean=6, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/5
# [8×8] Puzzle 6: clean=5, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/6
# [8×8] Puzzle 7: clean=7, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/7
# [8×8] Puzzle 8: clean=8, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/8
# ⚠️ Skipping 9: metadata file missing.
# [8×8] Puzzle 9 skipped due to missing metadata or tiles.
# [8×8] Puzzle 10: clean=10, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/10
# [8×8] Puzzle 11: clean=11, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/11
# [8×8] Puzzle 12: clean=12, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/12
# [8×8] Puzzle 13: clean=13, conf=0.983
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/13
# [8×8] Puzzle 14: clean=14, conf=0.980
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/14
# [8×8] Puzzle 15: clean=15, conf=0.980
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/15
# [8×8] Puzzle 16: clean=16, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/16
# [8×8] Puzzle 17: clean=17, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/17
# [8×8] Puzzle 18: clean=18, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/18
# [8×8] Puzzle 19: clean=19, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/19
# [8×8] Puzzle 20: clean=20, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/20
# [8×8] Puzzle 21: clean=21, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/21
# [8×8] Puzzle 22: clean=22, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/22
# [8×8] Puzzle 23: clean=23, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/23
# [8×8] Puzzle 24: clean=24, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/24
# [8×8] Puzzle 25: clean=25, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/25
# [8×8] Puzzle 26: clean=26, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/26
# [8×8] Puzzle 27: clean=27, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/27
# [8×8] Puzzle 28: clean=28, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/28
# [8×8] Puzzle 29: clean=29, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/29
# [8×8] Puzzle 30: clean=30, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/30
# [8×8] Puzzle 31: clean=32, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/31
# [8×8] Puzzle 32: clean=31, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/32
# [8×8] Puzzle 33: clean=34, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/33
# [8×8] Puzzle 34: clean=33, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/34
# [8×8] Puzzle 35: clean=35, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/35
# [8×8] Puzzle 36: clean=36, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/36
# [8×8] Puzzle 37: clean=37, conf=0.978
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/37
# [8×8] Puzzle 38: clean=38, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/38
# [8×8] Puzzle 39: clean=39, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/39
# [8×8] Puzzle 40: clean=40, conf=0.976
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/40
# [8×8] Puzzle 41: clean=43, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/41
# [8×8] Puzzle 42: clean=41, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/42
# [8×8] Puzzle 43: clean=42, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/43
# [8×8] Puzzle 44: clean=45, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/44
# [8×8] Puzzle 45: clean=44, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/45
# [8×8] Puzzle 46: clean=46, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/46
# [8×8] Puzzle 47: clean=47, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/47
# [8×8] Puzzle 48: clean=51, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/48
# [8×8] Puzzle 49: clean=49, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/49
# [8×8] Puzzle 50: clean=50, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/50
# [8×8] Puzzle 51: clean=48, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/51
# [8×8] Puzzle 52: clean=52, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/52
# [8×8] Puzzle 53: clean=54, conf=0.994
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/53
# [8×8] Puzzle 54: clean=53, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/54
# [8×8] Puzzle 55: clean=55, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/55
# [8×8] Puzzle 56: clean=56, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/56
# [8×8] Puzzle 57: clean=57, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/57
# [8×8] Puzzle 58: clean=58, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/58
# [8×8] Puzzle 59: clean=59, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/59
# [8×8] Puzzle 60: clean=60, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/60
# [8×8] Puzzle 61: clean=61, conf=0.986
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/61
# [8×8] Puzzle 62: clean=62, conf=0.992
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/62
# [8×8] Puzzle 63: clean=63, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/63
# [8×8] Puzzle 64: clean=64, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/64
# [8×8] Puzzle 65: clean=65, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/65
# [8×8] Puzzle 66: clean=66, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/66
# [8×8] Puzzle 67: clean=67, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/67
# [8×8] Puzzle 68: clean=68, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/68
# [8×8] Puzzle 69: clean=69, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/69
# [8×8] Puzzle 70: clean=70, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/70
# [8×8] Puzzle 71: clean=71, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/71
# [8×8] Puzzle 72: clean=72, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/72
# [8×8] Puzzle 73: clean=74, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/73
# [8×8] Puzzle 74: clean=73, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/74
# [8×8] Puzzle 75: clean=75, conf=0.995
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/75
# [8×8] Puzzle 76: clean=77, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/76
# [8×8] Puzzle 77: clean=78, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/77
# [8×8] Puzzle 78: clean=76, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/78
# [8×8] Puzzle 79: clean=79, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/79
# [8×8] Puzzle 80: clean=83, conf=0.988
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/80
# [8×8] Puzzle 81: clean=81, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/81
# [8×8] Puzzle 82: clean=82, conf=0.993
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/82
# [8×8] Puzzle 83: clean=80, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/83
# [8×8] Puzzle 84: clean=85, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/84
# [8×8] Puzzle 85: clean=84, conf=0.989
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/85
# [8×8] Puzzle 86: clean=86, conf=0.990
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/86
# [8×8] Puzzle 87: clean=87, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/87
# ⚠️ Puzzle 88: tile missing → 88_r7_c2.png
# ⚠️ Skipping puzzle 88 (incomplete tile set)
# [8×8] Puzzle 88 skipped due to missing metadata or tiles.
# ⚠️ Skipping 89: metadata file missing.
# [8×8] Puzzle 89 skipped due to missing metadata or tiles.
# [8×8] Puzzle 100: clean=100, conf=0.985
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/100
# [8×8] Puzzle 101: clean=101, conf=0.987
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/101
# [8×8] Puzzle 102: clean=102, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/102
# [8×8] Puzzle 103: clean=103, conf=0.981
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/103
# [8×8] Puzzle 104: clean=104, conf=0.980
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/104
# [8×8] Puzzle 105: clean=105, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/105
# [8×8] Puzzle 106: clean=106, conf=0.981
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/106
# [8×8] Puzzle 107: clean=107, conf=0.984
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/107
# [8×8] Puzzle 108: clean=108, conf=0.991
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/108
# [8×8] Puzzle 109: clean=109, conf=0.982
# ✔ Output saved → /content/drive/MyDrive/MS2_Solved/puzzle_8x8/109
# FINISHED SOLVING 8×8 PUZZLES
# ============================
# Solver A (matching): 97
# Solver B (metadata): 0
